# %%
f[x_] := 2*Log[(x - 1) / x] + 1

# %%
f[5]
# Out:
#           5
# 1 - 2 Log[-]
#           4

# %%
g1 = ((x - 1) / x) > 0
# Out:
# -1 + x
# ------ > 0
#   x

# %%
Reduce[g1, x]
# Out:
# x < 0 || x > 1

# %%
Plot[f[x], {x, -5, 5}]
# Out:
# -Graphics-

# %%
Manipulate[Plot[Sin[a x], {x, 0, 10}], {a, 1, 5}]
# Out:
# Manipulate[Plot[Sin[a x], {x, 0, 10}], {a, 1, 5}]

# %%
u = x^8 + x^6 - 3x^4 - 3x^3 + 8x^2 + 2x - 5;
v = 3x^6 + 5x^4 - 2x^2 - 9x + 21;
pquot[u, v, x]
# Out:
#         2
# -6 + 9 x

# %%
Factor[%]
# Out:
#            2
# 3 (-2 + 3 x )
